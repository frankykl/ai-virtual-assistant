# %% [markdown]
# ## Description
# This notebook demonstrates the usage of Unstructured Data Ingestion APIs.
#
# ## Usage Instructions
# Run each cell sequentially to execute the notebook.
# Note some cells are for reference and in order to not accidently excute them, they are marked as "Markdown".

# %%
IPADDRESS = "localhost" #Replace this with the correct IP address
UNSTRUCTURED_DATA_PORT = "8086"

# %% [markdown]
# ## Document Ingestion
# #### Get health of the document ingest service

# %%
import requests

url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/health'
print(url)
headers = {
    'accept': 'application/json'
}

response = requests.get(url, headers=headers)

# Print the response
print(response.status_code)
print(response.json())
# Out:
# http://localhost:8086/health
# 200
# {'message': 'Service is up.'}
# /Users/franklee/Work/frankykl_repos/ai-virtual-assistant/agent_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# #### Ingest Manuals (pdf)

# %%
import requests
import os
# URL of the API endpoint
url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/documents'
# Path to the PDF file you want to upload
directory_path = '../data/manuals_pdf'

# Loop through all files in the directory
for filename in os.listdir(directory_path):
    # Check if the file is a PDF
    if filename.endswith('.pdf'):
        file_path = os.path.join(directory_path, filename)

        # Open the file in binary mode and send it in a POST request
        with open(file_path, 'rb') as file:
            files = {'file': file}
            response = requests.post(url, files=files)

        # Print the response from the server
        print(f'Uploaded {filename}: {response.status_code}')
        print(response.json())
# Out:
# Uploaded GeForce_RTX_4070_QSG_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}
# Uploaded GeForce_RTX_4090_QSG_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}
# Uploaded GEFORCE_RTX_4080_SUPER_User_Guide_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}
# Uploaded GeForce_RTX_4080_QSG_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}
# Uploaded GEFORCE_RTX_4070_SUPER_User_Guide_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}
# Uploaded GEFORCE_RTX_4060_Ti_User_Guide_Rev1.pdf: 200
# {'message': 'File uploaded successfully'}

# %% [markdown]
# #### Ingest FAQs (pdf)

# %%
# URL of the API endpoint
import requests
url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/documents'
# Open the file in binary mode and send it in a POST request
filename = "../data/FAQ.pdf"
with open(filename, 'rb') as file:
    files = {'file': file}
    response = requests.post(url, files=files)

# Print the response from the server
print(f'Uploaded {filename}: {response.status_code}')
print(response.json())
# Out:
# Uploaded ../data/FAQ.pdf: 200
# {'message': 'File uploaded successfully'}

# %% [markdown]
# #### Get the list of documents

# %%
import requests

# URL of the API endpoint
url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/documents'

# Send the GET request
response = requests.get(url)

# Print the response from the server
print(f'Response Status Code: {response.status_code}')
#print(response.json())

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    documents = data.get('documents', [])

    # Format and print the list of documents
    print("Available Documents:")
    for idx, document in enumerate(documents, start=1):
        print(f"{idx}. {document}")
else:
    print(f"Failed to retrieve documents. Status Code: {response.status_code}")
# Out:
# Response Status Code: 200
# Available Documents:
# 1. FAQ
# 2. MENS_BEYOND_YOGA_CREW_T-SHIRT_-_DARKEST_NIGHT_Apparel_Mens
# 3. NVIDIA_ICONOGRAPHY_BANDANA_Lifestyle_Lifestyle
# 4. NVIDIA_GREEN_LABEL_BEANIE_Apparel_Mens
# 5. TIMBUK2_VAPOR_BACKPACK_TOTE_-_GRAPHITE_Bags_Bags
# 6. LONG_SLEEVE_PERFORMANCE_SHIRT_MENS_Apparel_Mens
# 7. NORTH_FACE_MENS_TREKKER_JACKET_Apparel_Mens
# 8. FULL_ZIP_NEURAL_HOODIE_UNISEX_Apparel_Mens
# 9. AUTONOMOUS_TIME_TRAVELER_TEE_UNISEX_Apparel_Mens
# 10. TOPO_ROVER_TECH_PACK_Bags_Bags
# 11. CHAMPION_REVERSE_WEAVE_CREWNECK_UNISEX_Apparel_Mens
# 12. GEFORCE_RTX_4070_SUPER_User_Guide_Rev1
# 13. SWELL_16OZ_PET_BOWL_Lifestyle_Lifestyle
# 14. RULER_Office_Office
# 15. 12_MARLED_KNIT_CUFF_BEANIE_Apparel_Mens
# 16. MENS_LULULEMON_ABC_JOGGER_Apparel_Mens
# 17. ANKLE_SOCK_UNISEX_Apparel_Mens
# 18. 32_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware
# 19. 25_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware
# 20. NVIDIA_HEX_SLING_BAG_-_GRAY_Bags_Bags
# 21. GEFORCE_40-SERIES_ALUMINUM_COASTER_Lifestyle_Lifestyle
# 22. WOMENS_BEYOND_YOGA_IN-STRIDE_PULLOVER_-_BLACK_Apparel_Womens
# 23. TOTE_BAG_Bags_Bags
# 24. NVIDIA_FLOW_LARGE_MOUSEPAD_Office_Office
# 25. GeForce_RTX_4070_QSG_Rev1
# 26. MARINE_LAYER_CORBET_FULL_ZIP_VEST_MENS_Apparel_Mens
# 27. GEFORCE_NOW_50_MEMBERSHIP_GIFT_CARD_NVIDIA_Electronics_Geforce
# 28. GEFORCE_RTX_4080_SUPER_User_Guide_Rev1
# 29. GEFORCE_RTX_4060_Ti_User_Guide_Rev1
# 30. 14_OZ._VISUAL_PURR-CEPTION_MUG_Drinkware_Drinkware
# 31. WOMENS_BEYOND_YOGA_MOVEMENT_SKIRT_Apparel_Womens
# 32. GEFORCE_ABSTRACTION_TEE_UNISEX_Apparel_Mens
# 33. NIKE_2.0_POLO_MENS_Apparel_Mens
# 34. TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Bags_Bags
# 35. LONG_SLEEVE_PERFORMANCE_SHIRT_WOMENS_Apparel_Womens
# 36. NVIDIA_GEFORCE_RTX_4090_NVIDIA_Electronics_Geforce
# 37. NVIDIA_ICONOGRAPHY_KRAFT_POCKET_JOURNAL_-3_PACK_Office_Office
# 38. NVIDIA_CORDUROY_HAT_Apparel_Mens
# 39. NVIDIA_JETSON_ORIN_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson
# 40. TIMBUK2_COPILOT_ROLLER_LUGGAGE_Bags_Bags
# 41. WOMENS_FLEECE_CROPPED_CREW_Apparel_Womens
# 42. GEFORCE_LOGO_HIGH_DENSITY_TEE_UNISEX_Apparel_Mens
# 43. GeForce_RTX_4080_QSG_Rev1
# 44. NVIDIA_DUO-TONE_LOGO_UNISEX_TEE_Apparel_Mens
# 45. UNISEX_INSPIRE_365_TEE_Apparel_Mens
# 46. JETSON_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson
# 47. NVIDIA_SHIELD_REMOTE_2020_NVIDIA_Electronics_Shield
# 48. 14_OZ._A_NEW_BREED_OF_INNOVATION_MUG_Drinkware_Drinkware
# 49. NEXT_LEVEL_ECO_UNISEX_TEE_UNISEX_Apparel_Mens
# 50. NVIDIA_NIMBLE_CHAMP_PRO_CHARGER_Lifestyle_Lifestyle
# 51. NVIDIA_TWILL_HAT_-_SAGE_Apparel_Mens
# 52. WIREFRAME_EYE_GRAPHIC_TEE_UNISEX_Apparel_Mens
# 53. MARINE_LAYER_CORBET_FULL_ZIP_VEST_WOMENS_Apparel_Womens
# 54. COMPUTER_CARE_KIT_Office_Office
# 55. NVIDIA_GEFORCE_RTX_4070_SUPER_NVIDIA_Electronics_Geforce
# 56. NVIDIA_ATHLETIC_CREW_SOCKS_Apparel_Mens
# 57. VICTORINOX_LAPTOP_WOMENS_TOTE_Bags_Bags
# 58. GeForce_RTX_4090_QSG_Rev1
# 59. MARINE_LAYER_CORBET_FULL_ZIP_MENS_Apparel_Mens
# 60. TIMBUK2_PARKSIDE_BACKPACK_2.0_Bags_Bags
# 61. CLUBMAN_SUNGLASSES_Lifestyle_Lifestyle
# 62. NVIDIA_GEFORCE_HAT_Apparel_Mens
# 63. NVIDIA_SMALL_INFINITY_MOUSEPAD_Office_Office
# 64. 20_OZ._ELEMENTAL_WATER_BOTTLE_Drinkware_Drinkware
# 65. NIKE_2.0_POLO_WOMENS_Apparel_Womens
# 66. 14_OZ._NVIDIA_LOGO_MUG_Drinkware_Drinkware
# 67. 14_OZ._I_AM_AI_MUG_Drinkware_Drinkware
# 68. NVIDIA_GEFORCE_RTX_4060TI_8GB_NVIDIA_Electronics_Geforce
# 69. UNISEX_TMYBTMYS_CUDA_TEE_Apparel_Mens
# 70. YOUTH_LOGO_TEE_Apparel_Kids
# 71. OGIO_STRATAGEM_BACKPACK_Bags_Bags
# 72. TROIKA_CONSTRUCTION_PEN_Office_Office
# 73. FLUX_BONDED_JACKET_WOMENS_LIGHT_HEATHER_Apparel_Womens
# 74. NVIDIA_LIGHTWEIGHT_HOODIE_Apparel_Mens
# 75. WOMENS_BEYOND_YOGA_SPACEDYE_RACERBACK_CROPPED_TANK_Apparel_Womens
# 76. HEROES_OF_NVIDIA_3.0_UNISEX_TEE_Apparel_Mens
# 77. TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Office_Office
# 78. NVIDIA_LICENSE_PLATE_FRAME_Lifestyle_Lifestyle
# 79. GEFORCE_TRIANGULATION_TEE_UNISEX_Apparel_Mens
# 80. INTENSITY_CLIC_GEL_PEN_Office_Office
# 81. OGIO_CATALYST_DUFFEL_-_BLACK_Bags_Bags
# 82. NVIDIA_GEFORCE_RTX_4070_NVIDIA_Electronics_Geforce
# 83. LAPEL_PIN_Lifestyle_Lifestyle
# 84. PORTABLE_FOLDING_CHAIR_Lifestyle_Lifestyle
# 85. COTTON_TOUCH_POLO_MENS_Apparel_Mens
# 86. GIFT_BAG_Bags_Bags
# 87. NORTH_FACE_WOMENS_TREKKER_JACKET_Apparel_Womens
# 88. WOMENS_LOGO_TEE_Apparel_Womens
# 89. MENS_LOGO_TEE_Apparel_Mens
# 90. MENS_BEYOND_YOGA_TAKE_IT_EASY_SHORTS_Apparel_Mens
# 91. FLUX_BONDED_JACKET_2.0_MENS_LIGHT_HEATHER_Apparel_Mens
# 92. PRODIR_PATTERN_PEN_Office_Office
# 93. COTTON_TOUCH_POLO_WOMENS_Apparel_Womens
# 94. NVIDIA_SHIELD_TV_PRO_2019_NVIDIA_Electronics_Shield
# 95. TITLEIST_PRO_V1_HALF_DOZEN_GOLF_BALLS_Lifestyle_Lifestyle
# 96. I_AM_AI_TEE_WOMENS_Apparel_Womens
# 97. NVIDIA_SHIELD_TV_2019_NVIDIA_Electronics_Shield
# 98. 40_OZ._STANLEY_QUENCHER_TUMBLER_Drinkware_Drinkware
# 99. WOMENS_V-NECK_TEE_Apparel_Womens
# 100. NVIDIA_GEFORCE_RTX_4080_NVIDIA_Electronics_Geforce
# 101. IGLOO_COAST_COOLER_Bags_Bags
# 102. I_AM_AI_TEE_MENS_Apparel_Mens
# 103. MENS_BEYOND_YOGA_TAKE_IT_EASY_PANT_-_DARKEST_NIGHT_Apparel_Mens
# 104. RULER_2.0_Office_Office
# 105. WOMENS_POCKET_LEGGINGS_Apparel_Womens
# 106. WOMENS_BEYOND_YOGA_REFOCUS_TANK_Apparel_Womens

# %% [markdown]
# ## Ingesting Product information from gear-store.csv
#
# Since the data is in csv file, but we support txt file for unstructured data ingestion. We will convert data into multiple text files and ingest them.

# %% [markdown]
# ### Display Data in csv file

# %%
# %%capture output
! pip install pandas
! pip install psycopg2-binary

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/gear-store.csv')

# %%
from IPython.display import display
display(df.head())
# Out:
#              category subcategory                                  name  \
# 0  NVIDIA Electronics     Geforce  GEFORCE NOW $50 MEMBERSHIP GIFT CARD
# 1  NVIDIA Electronics     Geforce             NVIDIA® GEFORCE RTX™ 4090
# 2  NVIDIA Electronics     Geforce             NVIDIA® GEFORCE RTX™ 4080
# 3  NVIDIA Electronics     Geforce             NVIDIA® GEFORCE RTX™ 4070
# 4  NVIDIA Electronics     Geforce       NVIDIA® GEFORCE™ RTX 4060TI 8GB
#
#                                          description   price
# 0  GeForce NOW gift cards can be redeemed for eit...    50.0
# 1  The NVIDIA® GeForce RTX® 4090 is the ultimate ...  1599.0
# 2  The NVIDIA® GeForce RTX™ 4080 delivers the ult...  1199.0
# 3  Get equipped for stellar gaming and creating w...   599.0
# 4  Game, stream, create. The GeForce RTX™ 4060 Ti...   299.0

# %%
len(df)
# Out:
# 99

# %% [markdown]
# ### Create *.txt file from csv data to ingest in canonical RAG

# %%
import os
import re

# Function to create a valid filename
def create_valid_filename(s):
    # Remove invalid characters and replace spaces with underscores
    s = re.sub(r'[^\w\-_\. ]', '', s)
    return s.replace(' ', '_')

# Create the directory if it doesn't exist
os.makedirs('../data/product', exist_ok=True)

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    # Create filename using name, category, and subcategory
    filename = f"{create_valid_filename(row['name'])}_{create_valid_filename(row['category'])}_{create_valid_filename(row['subcategory'])}.txt"

    print(f"Creating file {filename}, current index {index}")
    # Full path for the file
    filepath = os.path.join('../data/product', filename)

    # Create the content for the file
    content = f"Name: {row['name']}\n"
    content += f"Category: {row['category']}\n"
    content += f"Subcategory: {row['subcategory']}\n"
    content += f"Price: ${row['price']}\n"
    content += f"Description: {row['description']}\n"

    # Write the content to the file
    with open(filepath, 'w', encoding='utf-8') as file:
        file.write(content)

print(f"Created {len(df)} files in ../data/product")
# Out:
# Creating file GEFORCE_NOW_50_MEMBERSHIP_GIFT_CARD_NVIDIA_Electronics_Geforce.txt, current index 0
# Creating file NVIDIA_GEFORCE_RTX_4090_NVIDIA_Electronics_Geforce.txt, current index 1
# Creating file NVIDIA_GEFORCE_RTX_4080_NVIDIA_Electronics_Geforce.txt, current index 2
# Creating file NVIDIA_GEFORCE_RTX_4070_NVIDIA_Electronics_Geforce.txt, current index 3
# Creating file NVIDIA_GEFORCE_RTX_4060TI_8GB_NVIDIA_Electronics_Geforce.txt, current index 4
# Creating file NVIDIA_GEFORCE_RTX_4070_SUPER_NVIDIA_Electronics_Geforce.txt, current index 5
# Creating file NVIDIA_SHIELD_REMOTE_2020_NVIDIA_Electronics_Shield.txt, current index 6
# Creating file NVIDIA_SHIELD_TV_2019_NVIDIA_Electronics_Shield.txt, current index 7
# Creating file NVIDIA_SHIELD_TV_PRO_2019_NVIDIA_Electronics_Shield.txt, current index 8
# Creating file JETSON_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson.txt, current index 9
# Creating file NVIDIA_JETSON_ORIN_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson.txt, current index 10
# Creating file UNISEX_TMYBTMYS_CUDA_TEE_Apparel_Mens.txt, current index 11
# Creating file MENS_BEYOND_YOGA_CREW_T-SHIRT_-_DARKEST_NIGHT_Apparel_Mens.txt, current index 12
# Creating file MENS_BEYOND_YOGA_TAKE_IT_EASY_SHORTS_Apparel_Mens.txt, current index 13
# Creating file MENS_BEYOND_YOGA_TAKE_IT_EASY_PANT_-_DARKEST_NIGHT_Apparel_Mens.txt, current index 14
# Creating file MENS_LOGO_TEE_Apparel_Mens.txt, current index 15
# Creating file NEXT_LEVEL_ECO_UNISEX_TEE_UNISEX_Apparel_Mens.txt, current index 16
# Creating file NVIDIA_DUO-TONE_LOGO_UNISEX_TEE_Apparel_Mens.txt, current index 17
# Creating file UNISEX_INSPIRE_365_TEE_Apparel_Mens.txt, current index 18
# Creating file NORTH_FACE_MENS_TREKKER_JACKET_Apparel_Mens.txt, current index 19
# Creating file MARINE_LAYER_CORBET_FULL_ZIP_MENS_Apparel_Mens.txt, current index 20
# Creating file MARINE_LAYER_CORBET_FULL_ZIP_VEST_MENS_Apparel_Mens.txt, current index 21
# Creating file CHAMPION_REVERSE_WEAVE_CREWNECK_UNISEX_Apparel_Mens.txt, current index 22
# Creating file FLUX_BONDED_JACKET_2.0_MENS_LIGHT_HEATHER_Apparel_Mens.txt, current index 23
# Creating file FULL_ZIP_NEURAL_HOODIE_UNISEX_Apparel_Mens.txt, current index 24
# Creating file LONG_SLEEVE_PERFORMANCE_SHIRT_MENS_Apparel_Mens.txt, current index 25
# Creating file NIKE_2.0_POLO_MENS_Apparel_Mens.txt, current index 26
# Creating file COTTON_TOUCH_POLO_MENS_Apparel_Mens.txt, current index 27
# Creating file AUTONOMOUS_TIME_TRAVELER_TEE_UNISEX_Apparel_Mens.txt, current index 28
# Creating file GEFORCE_LOGO_HIGH_DENSITY_TEE_UNISEX_Apparel_Mens.txt, current index 29
# Creating file GEFORCE_TRIANGULATION_TEE_UNISEX_Apparel_Mens.txt, current index 30
# Creating file GEFORCE_ABSTRACTION_TEE_UNISEX_Apparel_Mens.txt, current index 31
# Creating file WIREFRAME_EYE_GRAPHIC_TEE_UNISEX_Apparel_Mens.txt, current index 32
# Creating file HEROES_OF_NVIDIA_3.0_UNISEX_TEE_Apparel_Mens.txt, current index 33
# Creating file I_AM_AI_TEE_MENS_Apparel_Mens.txt, current index 34
# Creating file MENS_LULULEMON_ABC_JOGGER_Apparel_Mens.txt, current index 35
# Creating file NVIDIA_TWILL_HAT_-_SAGE_Apparel_Mens.txt, current index 36
# Creating file 12_MARLED_KNIT_CUFF_BEANIE_Apparel_Mens.txt, current index 37
# Creating file NVIDIA_GREEN_LABEL_BEANIE_Apparel_Mens.txt, current index 38
# Creating file NVIDIA_GEFORCE_HAT_Apparel_Mens.txt, current index 39
# Creating file NVIDIA_CORDUROY_HAT_Apparel_Mens.txt, current index 40
# Creating file ANKLE_SOCK_UNISEX_Apparel_Mens.txt, current index 41
# Creating file NVIDIA_ATHLETIC_CREW_SOCKS_Apparel_Mens.txt, current index 42
# Creating file NVIDIA_LIGHTWEIGHT_HOODIE_Apparel_Mens.txt, current index 43
# Creating file YOUTH_LOGO_TEE_Apparel_Kids.txt, current index 44
# Creating file PORTABLE_FOLDING_CHAIR_Lifestyle_Lifestyle.txt, current index 45
# Creating file TITLEIST_PRO_V1_HALF_DOZEN_GOLF_BALLS_Lifestyle_Lifestyle.txt, current index 46
# Creating file LAPEL_PIN_Lifestyle_Lifestyle.txt, current index 47
# Creating file GEFORCE_40-SERIES_ALUMINUM_COASTER_Lifestyle_Lifestyle.txt, current index 48
# Creating file SWELL_16OZ_PET_BOWL_Lifestyle_Lifestyle.txt, current index 49
# Creating file NVIDIA_ICONOGRAPHY_BANDANA_Lifestyle_Lifestyle.txt, current index 50
# Creating file CLUBMAN_SUNGLASSES_Lifestyle_Lifestyle.txt, current index 51
# Creating file NVIDIA_NIMBLE_CHAMP_PRO_CHARGER_Lifestyle_Lifestyle.txt, current index 52
# Creating file NVIDIA_LICENSE_PLATE_FRAME_Lifestyle_Lifestyle.txt, current index 53
# Creating file 40_OZ._STANLEY_QUENCHER_TUMBLER_Drinkware_Drinkware.txt, current index 54
# Creating file 20_OZ._ELEMENTAL_WATER_BOTTLE_Drinkware_Drinkware.txt, current index 55
# Creating file 25_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware.txt, current index 56
# Creating file 32_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware.txt, current index 57
# Creating file 14_OZ._VISUAL_PURR-CEPTION_MUG_Drinkware_Drinkware.txt, current index 58
# Creating file 14_OZ._A_NEW_BREED_OF_INNOVATION_MUG_Drinkware_Drinkware.txt, current index 59
# Creating file 14_OZ._I_AM_AI_MUG_Drinkware_Drinkware.txt, current index 60
# Creating file 14_OZ._NVIDIA_LOGO_MUG_Drinkware_Drinkware.txt, current index 61
# Creating file TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Office_Office.txt, current index 62
# Creating file NVIDIA_SMALL_INFINITY_MOUSEPAD_Office_Office.txt, current index 63
# Creating file NVIDIA_FLOW_LARGE_MOUSEPAD_Office_Office.txt, current index 64
# Creating file NVIDIA_ICONOGRAPHY_KRAFT_POCKET_JOURNAL_-3_PACK_Office_Office.txt, current index 65
# Creating file RULER_2.0_Office_Office.txt, current index 66
# Creating file RULER_Office_Office.txt, current index 67
# Creating file TROIKA_CONSTRUCTION_PEN_Office_Office.txt, current index 68
# Creating file PRODIR_PATTERN_PEN_Office_Office.txt, current index 69
# Creating file INTENSITY_CLIC_GEL_PEN_Office_Office.txt, current index 70
# Creating file COMPUTER_CARE_KIT_Office_Office.txt, current index 71
# Creating file TIMBUK2_VAPOR_BACKPACK_TOTE_-_GRAPHITE_Bags_Bags.txt, current index 72
# Creating file NVIDIA_HEX_SLING_BAG_-_GRAY_Bags_Bags.txt, current index 73
# Creating file IGLOO_COAST_COOLER_Bags_Bags.txt, current index 74
# Creating file OGIO_CATALYST_DUFFEL_-_BLACK_Bags_Bags.txt, current index 75
# Creating file TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Bags_Bags.txt, current index 76
# Creating file TIMBUK2_PARKSIDE_BACKPACK_2.0_Bags_Bags.txt, current index 77
# Creating file VICTORINOX_LAPTOP_WOMENS_TOTE_Bags_Bags.txt, current index 78
# Creating file TOPO_ROVER_TECH_PACK_Bags_Bags.txt, current index 79
# Creating file TIMBUK2_COPILOT_ROLLER_LUGGAGE_Bags_Bags.txt, current index 80
# Creating file TOTE_BAG_Bags_Bags.txt, current index 81
# Creating file OGIO_STRATAGEM_BACKPACK_Bags_Bags.txt, current index 82
# Creating file GIFT_BAG_Bags_Bags.txt, current index 83
# Creating file WOMENS_BEYOND_YOGA_REFOCUS_TANK_Apparel_Womens.txt, current index 84
# Creating file WOMENS_BEYOND_YOGA_MOVEMENT_SKIRT_Apparel_Womens.txt, current index 85
# Creating file WOMENS_BEYOND_YOGA_IN-STRIDE_PULLOVER_-_BLACK_Apparel_Womens.txt, current index 86
# Creating file WOMENS_V-NECK_TEE_Apparel_Womens.txt, current index 87
# Creating file MARINE_LAYER_CORBET_FULL_ZIP_VEST_WOMENS_Apparel_Womens.txt, current index 88
# Creating file WOMENS_BEYOND_YOGA_SPACEDYE_RACERBACK_CROPPED_TANK_Apparel_Womens.txt, current index 89
# Creating file WOMENS_LOGO_TEE_Apparel_Womens.txt, current index 90
# Creating file WOMENS_FLEECE_CROPPED_CREW_Apparel_Womens.txt, current index 91
# Creating file NORTH_FACE_WOMENS_TREKKER_JACKET_Apparel_Womens.txt, current index 92
# Creating file FLUX_BONDED_JACKET_WOMENS_LIGHT_HEATHER_Apparel_Womens.txt, current index 93
# Creating file NIKE_2.0_POLO_WOMENS_Apparel_Womens.txt, current index 94
# Creating file COTTON_TOUCH_POLO_WOMENS_Apparel_Womens.txt, current index 95
# Creating file LONG_SLEEVE_PERFORMANCE_SHIRT_WOMENS_Apparel_Womens.txt, current index 96
# Creating file I_AM_AI_TEE_WOMENS_Apparel_Womens.txt, current index 97
# Creating file WOMENS_POCKET_LEGGINGS_Apparel_Womens.txt, current index 98
# Created 99 files in ../data/product

# %% [markdown]
# ### Ingest data from newly created text file in canonical RAG

# %%
import requests
import os
import time

# Retry configuration (Added due to rate limits for API Catalog embedding model )
MAX_RETRIES = 5
INITIAL_BACKOFF = 1  # Initial backoff in seconds

def ingest_file(filepath: str) -> bool:
    """
    Ingest file in canonical RAG retriever with retry mechanism

    Args:
        filepath: Path to the file to be ingested in retriever

    Returns:
        bool: Status of file ingestion
    """
    # URL of the API endpoint
    url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/documents'
    retries = 0
    backoff = INITIAL_BACKOFF

    while retries <= MAX_RETRIES:
        with open(filepath, 'rb') as file:
            files = {'file': file}
            try:
                response = requests.post(url, files=files)

                if response.status_code == 200:
                    return True
                elif response.status_code != 200:  # Handle Too Many Requests error
                    if retries < MAX_RETRIES:
                        print(f"Internal Server error for {os.path.basename(filepath)}. Retrying after {backoff}s...")
                        time.sleep(backoff)
                        backoff *= 2  # Exponential backoff
                        retries += 1
                    else:
                        print(f"Max retries reached for {os.path.basename(filepath)}. Giving up.")
                        return False

            except requests.exceptions.RequestException as e:
                print(f"Request failed for {os.path.basename(filepath)}: {e}")
                return False

    return False

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

directory_path = '../data/product'
max_workers = 5  # Adjust this based on your system's capabilities and API limits

filepaths = [os.path.join(directory_path, filename) for filename in os.listdir(directory_path) if filename.endswith(".txt")]
filepaths

successfully_ingested = []
failed_ingestion = []

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    future_to_file = {executor.submit(ingest_file, filepath): filepath for filepath in filepaths}

    for future in as_completed(future_to_file):
        filepath = future_to_file[future]
        try:
            if future.result():
                print(f"Successfully Ingested {os.path.basename(filepath)}")
                successfully_ingested.append(filepath)
            else:
                print(f"Failed to Ingest {os.path.basename(filepath)}")
                failed_ingestion.append(filepath)
        except Exception as e:
            print(f"Exception occurred while ingesting {os.path.basename(filepath)}: {e}")
            # traceback.print_exc()
            failed_ingestion.append(filepath)

print(f"Total files successfully ingested: {len(successfully_ingested)}")
print(f"Total files failed ingestion: {len(failed_ingestion)}")
# Out:
# Successfully Ingested MARINE_LAYER_CORBET_FULL_ZIP_VEST_WOMENS_Apparel_Womens.txt
# Successfully Ingested TIMBUK2_COPILOT_ROLLER_LUGGAGE_Bags_Bags.txt
# Successfully Ingested NVIDIA_GEFORCE_RTX_4070_SUPER_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested NVIDIA_CORDUROY_HAT_Apparel_Mens.txt
# Successfully Ingested 12_MARLED_KNIT_CUFF_BEANIE_Apparel_Mens.txt
# Successfully Ingested NVIDIA_SHIELD_TV_PRO_2019_NVIDIA_Electronics_Shield.txt
# Successfully Ingested WIREFRAME_EYE_GRAPHIC_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested GIFT_BAG_Bags_Bags.txt
# Successfully Ingested NORTH_FACE_MENS_TREKKER_JACKET_Apparel_Mens.txt
# Successfully Ingested NVIDIA_GEFORCE_RTX_4060TI_8GB_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested MENS_BEYOND_YOGA_TAKE_IT_EASY_PANT_-_DARKEST_NIGHT_Apparel_Mens.txt
# Successfully Ingested TIMBUK2_VAPOR_BACKPACK_TOTE_-_GRAPHITE_Bags_Bags.txt
# Successfully Ingested NVIDIA_ICONOGRAPHY_KRAFT_POCKET_JOURNAL_-3_PACK_Office_Office.txt
# Successfully Ingested SWELL_16OZ_PET_BOWL_Lifestyle_Lifestyle.txt
# Successfully Ingested COTTON_TOUCH_POLO_MENS_Apparel_Mens.txt
# Successfully Ingested FLUX_BONDED_JACKET_2.0_MENS_LIGHT_HEATHER_Apparel_Mens.txt
# Successfully Ingested PRODIR_PATTERN_PEN_Office_Office.txt
# Successfully Ingested NVIDIA_FLOW_LARGE_MOUSEPAD_Office_Office.txt
# Successfully Ingested GEFORCE_ABSTRACTION_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested RULER_Office_Office.txt
# Successfully Ingested NVIDIA_GEFORCE_RTX_4080_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested WOMENS_FLEECE_CROPPED_CREW_Apparel_Womens.txt
# Successfully Ingested TOPO_ROVER_TECH_PACK_Bags_Bags.txt
# Successfully Ingested CLUBMAN_SUNGLASSES_Lifestyle_Lifestyle.txt
# Successfully Ingested WOMENS_BEYOND_YOGA_IN-STRIDE_PULLOVER_-_BLACK_Apparel_Womens.txt
# Successfully Ingested TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Bags_Bags.txt
# Successfully Ingested I_AM_AI_TEE_WOMENS_Apparel_Womens.txt
# Successfully Ingested FLUX_BONDED_JACKET_WOMENS_LIGHT_HEATHER_Apparel_Womens.txt
# Successfully Ingested GEFORCE_40-SERIES_ALUMINUM_COASTER_Lifestyle_Lifestyle.txt
# Successfully Ingested GEFORCE_LOGO_HIGH_DENSITY_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested NIKE_2.0_POLO_MENS_Apparel_Mens.txt
# Successfully Ingested PORTABLE_FOLDING_CHAIR_Lifestyle_Lifestyle.txt
# Successfully Ingested OGIO_STRATAGEM_BACKPACK_Bags_Bags.txt
# Successfully Ingested COTTON_TOUCH_POLO_WOMENS_Apparel_Womens.txt
# Successfully Ingested NVIDIA_SMALL_INFINITY_MOUSEPAD_Office_Office.txt
# Successfully Ingested LONG_SLEEVE_PERFORMANCE_SHIRT_WOMENS_Apparel_Womens.txt
# Successfully Ingested UNISEX_TMYBTMYS_CUDA_TEE_Apparel_Mens.txt
# Successfully Ingested TOTE_BAG_Bags_Bags.txt
# Successfully Ingested MARINE_LAYER_CORBET_FULL_ZIP_MENS_Apparel_Mens.txt
# Successfully Ingested 14_OZ._VISUAL_PURR-CEPTION_MUG_Drinkware_Drinkware.txt
# Successfully Ingested NVIDIA_JETSON_ORIN_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson.txt
# Successfully Ingested NVIDIA_ATHLETIC_CREW_SOCKS_Apparel_Mens.txt
# Successfully Ingested 25_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware.txt
# Successfully Ingested MENS_LOGO_TEE_Apparel_Mens.txt
# Successfully Ingested WOMENS_LOGO_TEE_Apparel_Womens.txt
# Successfully Ingested 14_OZ._A_NEW_BREED_OF_INNOVATION_MUG_Drinkware_Drinkware.txt
# Successfully Ingested NIKE_2.0_POLO_WOMENS_Apparel_Womens.txt
# Successfully Ingested GEFORCE_NOW_50_MEMBERSHIP_GIFT_CARD_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested LONG_SLEEVE_PERFORMANCE_SHIRT_MENS_Apparel_Mens.txt
# Successfully Ingested TROIKA_CONSTRUCTION_PEN_Office_Office.txt
# Successfully Ingested JETSON_NANO_DEVELOPER_KIT_NVIDIA_Electronics_Jetson.txt
# Successfully Ingested YOUTH_LOGO_TEE_Apparel_Kids.txt
# Successfully Ingested CHAMPION_REVERSE_WEAVE_CREWNECK_UNISEX_Apparel_Mens.txt
# Successfully Ingested NVIDIA_GEFORCE_HAT_Apparel_Mens.txt
# Successfully Ingested NVIDIA_SHIELD_TV_2019_NVIDIA_Electronics_Shield.txt
# Successfully Ingested TIMBUK2_PARKSIDE_BACKPACK_2.0_Bags_Bags.txt
# Successfully Ingested NVIDIA_LIGHTWEIGHT_HOODIE_Apparel_Mens.txt
# Successfully Ingested MENS_BEYOND_YOGA_TAKE_IT_EASY_SHORTS_Apparel_Mens.txt
# Successfully Ingested 40_OZ._STANLEY_QUENCHER_TUMBLER_Drinkware_Drinkware.txt
# Successfully Ingested NVIDIA_NIMBLE_CHAMP_PRO_CHARGER_Lifestyle_Lifestyle.txt
# Successfully Ingested NVIDIA_ICONOGRAPHY_BANDANA_Lifestyle_Lifestyle.txt
# Successfully Ingested 14_OZ._I_AM_AI_MUG_Drinkware_Drinkware.txt
# Successfully Ingested 32_OZ._NVIDIA_ICONOGRAPHY_BOTTLE_Drinkware_Drinkware.txt
# Successfully Ingested HEROES_OF_NVIDIA_3.0_UNISEX_TEE_Apparel_Mens.txt
# Successfully Ingested VICTORINOX_LAPTOP_WOMENS_TOTE_Bags_Bags.txt
# Successfully Ingested UNISEX_INSPIRE_365_TEE_Apparel_Mens.txt
# Successfully Ingested NVIDIA_HEX_SLING_BAG_-_GRAY_Bags_Bags.txt
# Successfully Ingested ANKLE_SOCK_UNISEX_Apparel_Mens.txt
# Successfully Ingested NVIDIA_GEFORCE_RTX_4070_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested LAPEL_PIN_Lifestyle_Lifestyle.txt
# Successfully Ingested IGLOO_COAST_COOLER_Bags_Bags.txt
# Successfully Ingested NORTH_FACE_WOMENS_TREKKER_JACKET_Apparel_Womens.txt
# Successfully Ingested I_AM_AI_TEE_MENS_Apparel_Mens.txt
# Successfully Ingested NVIDIA_SHIELD_REMOTE_2020_NVIDIA_Electronics_Shield.txt
# Successfully Ingested GEFORCE_TRIANGULATION_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested WOMENS_BEYOND_YOGA_SPACEDYE_RACERBACK_CROPPED_TANK_Apparel_Womens.txt
# Successfully Ingested RULER_2.0_Office_Office.txt
# Successfully Ingested TITLEIST_PRO_V1_HALF_DOZEN_GOLF_BALLS_Lifestyle_Lifestyle.txt
# Successfully Ingested FULL_ZIP_NEURAL_HOODIE_UNISEX_Apparel_Mens.txt
# Successfully Ingested WOMENS_POCKET_LEGGINGS_Apparel_Womens.txt
# Successfully Ingested TIMBUK2_LAPTOP_SLEEVE_-_2_SIZES_Office_Office.txt
# Successfully Ingested WOMENS_V-NECK_TEE_Apparel_Womens.txt
# Successfully Ingested 20_OZ._ELEMENTAL_WATER_BOTTLE_Drinkware_Drinkware.txt
# Successfully Ingested INTENSITY_CLIC_GEL_PEN_Office_Office.txt
# Successfully Ingested NVIDIA_DUO-TONE_LOGO_UNISEX_TEE_Apparel_Mens.txt
# Successfully Ingested NEXT_LEVEL_ECO_UNISEX_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested NVIDIA_TWILL_HAT_-_SAGE_Apparel_Mens.txt
# Successfully Ingested MARINE_LAYER_CORBET_FULL_ZIP_VEST_MENS_Apparel_Mens.txt
# Successfully Ingested WOMENS_BEYOND_YOGA_REFOCUS_TANK_Apparel_Womens.txt
# Successfully Ingested WOMENS_BEYOND_YOGA_MOVEMENT_SKIRT_Apparel_Womens.txt
# Successfully Ingested COMPUTER_CARE_KIT_Office_Office.txt
# Successfully Ingested MENS_BEYOND_YOGA_CREW_T-SHIRT_-_DARKEST_NIGHT_Apparel_Mens.txt
# Successfully Ingested 14_OZ._NVIDIA_LOGO_MUG_Drinkware_Drinkware.txt
# Successfully Ingested OGIO_CATALYST_DUFFEL_-_BLACK_Bags_Bags.txt
# Successfully Ingested NVIDIA_LICENSE_PLATE_FRAME_Lifestyle_Lifestyle.txt
# Successfully Ingested AUTONOMOUS_TIME_TRAVELER_TEE_UNISEX_Apparel_Mens.txt
# Successfully Ingested MENS_LULULEMON_ABC_JOGGER_Apparel_Mens.txt
# Successfully Ingested NVIDIA_GEFORCE_RTX_4090_NVIDIA_Electronics_Geforce.txt
# Successfully Ingested NVIDIA_GREEN_LABEL_BEANIE_Apparel_Mens.txt
# Total files successfully ingested: 99
# Total files failed ingestion: 0

# %% [markdown]
# #### (For reference) Delete a document
#
# The cell is in "raw" and does not execute. This code is for reference alone.

# %% [raw]
# import requests
#
# # URL of the API endpoint
# url = f'http://{IPADDRESS}:{UNSTRUCTURED_DATA_PORT}/documents'
#
# # Filename of the document to delete
# filename = 'GEFORCE_RTX_4070_SUPER_User_Guide_Rev1'
#
# # Parameters to be sent with the DELETE request
# params = {'filename': filename}
#
# # Send the DELETE request
# response = requests.delete(url, params=params)
#
# # Print the response from the server
# print(f'Response Status Code: {response.status_code}')
# print(response.json())

# %% [markdown]
# ### Ingest the customer order history data into a postgres db

# %%
import csv
import re
import psycopg2
from datetime import datetime

# Database connection parameters
db_params = {
    'dbname': 'customer_data',
    'user': 'postgres',
    'password': 'password',
    'host': IPADDRESS,  # e.g., 'localhost' or the IP address
    'port': '5432'   # e.g., '5432'
}

# CSV file path
csv_file_path = '../data/orders.csv'

# Connect to the database
conn = psycopg2.connect(**db_params)
cur = conn.cursor()

# Create the table if it doesn't exist
create_table_query = '''
CREATE TABLE IF NOT EXISTS customer_data (
    customer_id INTEGER NOT NULL,
    order_id INTEGER NOT NULL,
    product_name VARCHAR(255) NOT NULL,
    product_description VARCHAR NOT NULL,
    order_date DATE NOT NULL,
    quantity INTEGER NOT NULL,
    order_amount DECIMAL(10, 2) NOT NULL,
    order_status VARCHAR(50),
    return_status VARCHAR(50),
    return_start_date DATE,
    return_received_date DATE,
    return_completed_date DATE,
    return_reason VARCHAR(255),
    notes TEXT,
    PRIMARY KEY (customer_id, order_id)
);
'''
cur.execute(create_table_query)

# Open the CSV file and insert data
with open(csv_file_path, 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row

    for row in reader:
        # Access columns by index as per the provided structure
        order_id = int(row[1])  # OrderID
        customer_id = int(row[0])  # CID (Customer ID)

        # Correcting the order date to include time
        order_date = datetime.strptime(row[4], "%Y-%m-%dT%H:%M:%S")  # OrderDate with time

        quantity = int(row[5])  # Quantity

        # Handle optional date fields with time parsing
        return_start_date = datetime.strptime(row[9], "%Y-%m-%dT%H:%M:%S") if row[9] else None  # ReturnStartDate
        return_received_date = datetime.strptime(row[10],"%Y-%m-%dT%H:%M:%S") if row[10] else None  # ReturnReceivedDate
        return_completed_date = datetime.strptime(row[11], "%Y-%m-%dT%H:%M:%S") if row[11] else None  # ReturnCompletedDate

        # Clean product name
        product_name = re.sub(r'[®™]', '', row[2])  # ProductName

        product_description = re.sub(r'[®™]', '', row[3])
        # OrderAmount as float
        order_amount = float(row[6].replace(',', ''))

        # Insert data into the database
        cur.execute(
            '''
            INSERT INTO customer_data (
                customer_id, order_id, product_name, product_description, order_date, quantity, order_amount,
                order_status, return_status, return_start_date, return_received_date,
                return_completed_date, return_reason, notes
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            ''',
            (customer_id, order_id, product_name, product_description, order_date, quantity, order_amount,
             row[7],  # OrderStatus
             row[8],  # ReturnStatus
             return_start_date, return_received_date, return_completed_date,
             row[12],  # ReturnReason
             row[13])  # Notes
        )

# Commit the changes and close the connection
conn.commit()
cur.close()
conn.close()

print("CSV Data imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[14], line 72
#      69         order_amount = float(row[6].replace(',', ''))
#      71         # Insert data into the database
# ---> 72         cur.execute(
#      73             '''
#      74             INSERT INTO customer_data (
#      75                 customer_id, order_id, product_name, product_description, order_date, quantity, order_amount,
#      76                 order_status, return_status, return_start_date, return_received_date,
#      77                 return_completed_date, return_reason, notes
#      78             ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#      79             ''',
#      80             (customer_id, order_id, product_name, product_description, order_date, quantity, order_amount,
#      81              row[7],  # OrderStatus
#      82              row[8],  # ReturnStatus
#      83              return_start_date, return_received_date, return_completed_date,
#      84              row[12],  # ReturnReason
#      85              row[13])  # Notes
#      86         )
#      88 # Commit the changes and close the connection
#      89 conn.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "customer_data_pkey"
# DETAIL:  Key (customer_id, order_id)=(4165, 52768) already exists.

# %% [markdown]
# #### Read the data to ensure it was written

# %%
import psycopg2

# Database connection parameters
db_params = {
    'dbname': 'customer_data',
    'user': 'postgres',
    'password': 'password',
    'host': IPADDRESS,  # e.g., 'localhost' or the IP address
    'port': '5432'   # e.g., '5432'
}

# Connect to the database
conn = psycopg2.connect(**db_params)
cur = conn.cursor()

# Query to select the first 5 rows from the customer_data table
query = 'SELECT * FROM customer_data LIMIT 5;'

# Execute the query
cur.execute(query)

# Fetch the column headers
colnames = [desc[0] for desc in cur.description]

# Fetch the first 5 rows
rows = cur.fetchall()

# Print the headers and the corresponding rows
for i, row in enumerate(rows, start=1):
    print(f"\nRow {i}:")
    for header, value in zip(colnames, row):
        print(f"{header}: {value}")

# Close the connection
cur.close()
conn.close()
# Out:
# Row 1:
# customer_id: 4165
# order_id: 52768
# product_name: JETSON NANO DEVELOPER KIT
# product_description: The power of modern AI is now available for makers, learners, and embedded developers everywhere.
#
# NVIDIA Jetson Nano Developer Kit is a small, powerful computer that lets you run multiple neural networks in parallel for applications like image classification, object detection, segmentation, and speech processing. All in an easy-to-use platform that runs in as little as 5 watts.
#
# It’s simpler than ever to get started! Just insert a microSD card with the system image, boot the developer kit, and enjoy using the same NVIDIA JetPack SDK used across the NVIDIA Jetson family of products.
#
# This version of Jetson Nano Developer Kit has two camera connectors.
# order_date: 2024-10-05
# quantity: 2
# order_amount: 298.00
# order_status: Delivered
# return_status:
# return_start_date: None
# return_received_date: None
# return_completed_date: None
# return_reason:
# notes:
#
# Row 2:
# customer_id: 4165
# order_id: 4065
# product_name: NVIDIA GEFORCE RTX 4090
# product_description: The NVIDIA GeForce RTX 4090 is the ultimate GeForce GPU. It brings an enormous leap in performance, efficiency, and AI-powered graphics. Experience ultra-high performance gaming, incredibly detailed virtual worlds, unprecedented productivity, and new ways to create. It’s powered by the NVIDIA Ada Lovelace architecture and comes with 24 GB of G6X memory to deliver the ultimate experience for gamers and creators.
#
# CUDA Cores: 16384
# Boost Clock: 2.52 GHz
# Memory Configuration: 24GB GDDR6X
#
# Please refer to the graphics card comparison page for a full list of specifications: https://www.nvidia.com/en-us/geforce/graphics-cards/compare/
# order_date: 2024-10-10
# quantity: 1
# order_amount: 1599.00
# order_status: Return Requested
# return_status: Requested
# return_start_date: 2024-10-12
# return_received_date: None
# return_completed_date: None
# return_reason: Received a faulty unit that doesn't display correctly.
# notes:
#
# Row 3:
# customer_id: 4165
# order_id: 69268
# product_name: NVIDIA GEFORCE RTX 4070
# product_description: Get equipped for stellar gaming and creating with the NVIDIA GeForce RTX 4070. It’s built with the ultra-efficient NVIDIA Ada Lovelace architecture. Experience fast ray tracing, AI-accelerated performance with DLSS 3, new ways to create, and much more.
#
# CUDA Cores: 5888
# Boost Clock: 2.48 GHz
# Memory Configuration: 12GB GDDR6X
# Model 900-1G141-2544-000
# order_date: 2024-10-01
# quantity: 1
# order_amount: 599.00
# order_status: Delivered
# return_status:
# return_start_date: None
# return_received_date: None
# return_completed_date: None
# return_reason:
# notes:
#
# Row 4:
# customer_id: 4165
# order_id: 71110
# product_name: NVIDIA SHIELD REMOTE (2020)
# product_description: Motion-activated, backlit buttons
# Mic for voice search and control
# Bluetooth connectivity
# IR for TV control
# Built-in lost remote locator
# 930-13700-2500-100
# order_date: 2024-10-15
# quantity: 3
# order_amount: 164.97
# order_status: Returned
# return_status: Approved
# return_start_date: None
# return_received_date: 2024-10-18
# return_completed_date: 2024-11-02
# return_reason: Item stopped functioning correctly within a week.
# notes:
#
# Row 5:
# customer_id: 4165
# order_id: 15620
# product_name: NVIDIA SHIELD TV PRO 2019
# product_description: NVIDIA SHIELD TV Pro is the supreme streaming media player - packed with features to make even the most demanding users proud. Beautifully designed to be the perfect centerpiece of your entertainment center. Enjoy a cinematic experience with stunning visuals brought to you by Dolby Vision HDR, and immersive audio with Dolby Atmos surround sound. Now powered by the latest NVIDIA Tegra X1+ processor, SHIELD TV is faster, and smarter. Level up to SHIELD TV Pro for more storage space, two USB 3.0 ports for expandability (storage expansion, USB cameras, USB keyboards and controllers, TV tuners, and more), Plex Media Server, SmartThings hub-ready (just add a SmartThings Link), AAA Android gaming, Twitch broadcasting, and 3GB RAM.
# order_date: 2024-10-03
# quantity: 1
# order_amount: 199.99
# order_status: Delivered
# return_status:
# return_start_date: None
# return_received_date: None
# return_completed_date: None
# return_reason:
# notes:

# %% [markdown]
# #### (For reference)Drop the postgres table
#
# The cell is in raw format and does not execute. This code is for reference alone.

# %% [raw]
# # pip install psycopg2-binary
# import psycopg2
#
# # Database connection parameters
# db_params = {
#     'dbname': 'customer_data',
#     'user': 'postgres',
#     'password': 'password',
#     'host': IPADDRESS,  # e.g., 'localhost' or the IP address
#     'port': '5432'   # e.g., '5432'
# }
#
# # Connect to the database
# conn = psycopg2.connect(**db_params)
# cur = conn.cursor()
#
# # Drop the table if it exists
# drop_table_query = 'DROP TABLE IF EXISTS customer_data;'
#
# # Execute the drop query
# cur.execute(drop_table_query)
#
# # Commit the changes and close the connection
# conn.commit()
# cur.close()
# conn.close()
#
# print("Table 'customer_data' dropped successfully!")
